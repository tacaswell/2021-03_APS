# %%
# interactive figures, requires ipypml!
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
from gen_data import get_data
d = get_data(25)
d
# Out:
# <xarray.DataArray (control: 25, time: 4112)>
# array([[ 2.01186205e+00,  2.06044465e+00,  2.01706902e+00, ...,
#          6.22418527e-02,  6.37764399e-02,  5.47344874e-02],
#        [ 1.99890617e+00,  1.97017777e+00,  1.88155773e+00, ...,
#          9.87884246e-02,  5.56025446e-02, -1.66491998e-03],
#        [ 1.99208773e+00,  1.93796074e+00,  2.03084200e+00, ...,
#         -4.69389308e-02,  5.27816257e-02,  4.60638065e-02],
#        ...,
#        [ 1.98825312e+00,  2.01150995e+00,  1.94276606e+00, ...,
#          2.58743212e-02, -4.78450785e-02,  3.65490321e-02],
#        [ 1.97477545e+00,  2.03470600e+00,  1.99633782e+00, ...,
#         -5.78889460e-02,  5.40627885e-02,  6.92298633e-02],
#        [ 2.02396534e+00,  1.97328635e+00,  2.03224400e+00, ...,
#          2.35647386e-02,  7.47068825e-02,  9.56075011e-02]])
# Coordinates:
#   * control  (control) float64 15.0 15.62 16.25 16.88 ... 28.12 28.75 29.38 30.0
# ...

# %%
fig, ax = plt.subplots()
ax.plot(d.T)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %%
m = d[5]
m
# Out:
# <xarray.DataArray (time: 4112)>
# array([ 2.00159577,  2.0395333 ,  1.88476958, ...,  0.04526297,
#        -0.07571083,  0.00821341])
# Coordinates:
#     control  float64 18.12
#   * time     (time) float64 0.0 0.007642 0.01528 0.02293 ... 31.4 31.41 31.42

# %%
fig, ax = plt.subplots()
# ax.plot(m)
# ax.plot(m.time, m)
m.plot(ax=ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
